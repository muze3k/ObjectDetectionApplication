# %%
from google.colab import drive

drive.mount('my-drive')
# Out:
# Drive already mounted at my-drive; to attempt to forcibly remount, call drive.mount("my-drive", force_remount=True).

# %%
ROOT_DIR = '/content/my-drive/MyDrive/objectTracking/'

# %%
# !pip install ultralytics

# %%
import os
from ultralytics import YOLO

model = YOLO('yolov8.yaml')
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
results = model.train(data=os.path.join(ROOT_DIR, 'dataset.yaml'), epochs=100)
# Out:
# Ultralytics YOLOv8.0.190 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
r = model.val()
# Out:
# Ultralytics YOLOv8.0.190 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8 summary (fused): 168 layers, 3008768 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/my-drive/MyDrive/objectTracking/data/labels/train.cache... 40 images, 0 backgrounds, 0 corrupt: 100%|██████████| 40/40 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:02<00:00,  1.41it/s]
#                    all         40         40      0.168      0.125      0.149     0.0502
#                  knife         40         40      0.168      0.125      0.149     0.0502
# Speed: 5.3ms preprocess, 21.7ms inference, 0.0ms loss, 6.1ms postprocess per image
# Results saved to runs/detect/val

# %%
model1 = YOLO('yolov8n.pt')

# %%
results1 = model1.train(data=os.path.join(ROOT_DIR, 'dataset.yaml'), epochs=100)
# Out:
# Ultralytics YOLOv8.0.190 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !scp -r /content/runs '/content/my-drive/MyDrive/objectTracking/trainingRuns'
